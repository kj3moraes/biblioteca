# %%
import os
import cv2
import numpy as np
import torch
from segment_anything import build_sam, sam_model_registry, SamPredictor
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 5
#       3 import numpy as np
#       4 import torch
# ----> 5 from segment_anything import build_sam, sam_model_registry, SamPredictor
#       6 from PIL import Image
#       7 import matplotlib.pyplot as plt
#
# File ~/Projects/Coding/biblioteca/.venv/lib/python3.11/site-packages/segment_anything/__init__.py:14
#       1 # Copyright (c) Meta Platforms, Inc. and affiliates.
#       2 # All rights reserved.
#       3
#       4 # This source code is licensed under the license found in the
#       5 # LICENSE file in the root directory of this source tree.
#       7 from .build_sam import (
#       8     build_sam,
#       9     build_sam_vit_h,
#    (...)     12     sam_model_registry,
#      13 )
# ---> 14 from .predictor import SamPredictor
#      15 from .automatic_mask_generator import SamAutomaticMaskGenerator
#
# File ~/Projects/Coding/biblioteca/.venv/lib/python3.11/site-packages/segment_anything/predictor.py:14
#      10 from segment_anything.modeling import Sam
#      12 from typing import Optional, Tuple
# ---> 14 from .utils.transforms import ResizeLongestSide
#      17 class SamPredictor:
#      18     def __init__(
#      19         self,
#      20         sam_model: Sam,
#      21     ) -> None:
#
# File ~/Projects/Coding/biblioteca/.venv/lib/python3.11/site-packages/segment_anything/utils/transforms.py:10
#       8 import torch
#       9 from torch.nn import functional as F
# ---> 10 from torchvision.transforms.functional import resize, to_pil_image  # type: ignore
#      12 from copy import deepcopy
#      13 from typing import Tuple
#
# File ~/Projects/Coding/biblioteca/.venv/lib/python3.11/site-packages/torchvision/__init__.py:10
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#      13     from .version import __version__  # noqa: F401
#
# File ~/Projects/Coding/biblioteca/.venv/lib/python3.11/site-packages/torchvision/models/__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# File ~/Projects/Coding/biblioteca/.venv/lib/python3.11/site-packages/torchvision/models/convnext.py:9
#       6 from torch import nn, Tensor
#       7 from torch.nn import functional as F
# ----> 9 from ..ops.misc import Conv2dNormActivation, Permute
#      10 from ..ops.stochastic_depth import StochasticDepth
#      11 from ..transforms._presets import ImageClassification
#
# File ~/Projects/Coding/biblioteca/.venv/lib/python3.11/site-packages/torchvision/ops/__init__.py:1
# ----> 1 from ._register_onnx_ops import _register_custom_op
#       2 from .boxes import (
#       3     batched_nms,
#       4     box_area,
#    (...)     13     remove_small_boxes,
#      14 )
#      15 from .ciou_loss import complete_box_iou_loss
#
# File ~/Projects/Coding/biblioteca/.venv/lib/python3.11/site-packages/torchvision/ops/_register_onnx_ops.py:5
#       2 import warnings
#       4 import torch
# ----> 5 from torch.onnx import symbolic_opset11 as opset11
#       6 from torch.onnx.symbolic_helper import parse_args
#       8 _ONNX_OPSET_VERSION_11 = 11
#
# File ~/Projects/Coding/biblioteca/.venv/lib/python3.11/site-packages/torch/onnx/__init__.py:74
#      64 from .errors import OnnxExporterError
#      65 from .utils import (
#      66     _run_symbolic_function,
#      67     _run_symbolic_method,
#    (...)     70     unregister_custom_op_symbolic,
#      71 )
# ---> 74 from . import (  # usort: skip. Keep the order instead of sorting lexicographically
#      75     errors,
#      76     ops,
#      77     symbolic_caffe2,
#      78     symbolic_helper,
#      79     symbolic_opset7,
#      80     symbolic_opset8,
#      81     symbolic_opset9,
#      82     symbolic_opset10,
#      83     symbolic_opset11,
#      84     symbolic_opset12,
#      85     symbolic_opset13,
#      86     symbolic_opset14,
#      87     symbolic_opset15,
#      88     symbolic_opset16,
#      89     symbolic_opset17,
#      90     symbolic_opset18,
#      91     symbolic_opset19,
#      92     symbolic_opset20,
#      93     utils,
#      94 )
#      97 if TYPE_CHECKING:
#      98     import os
#
# File ~/Projects/Coding/biblioteca/.venv/lib/python3.11/site-packages/torch/onnx/ops/__init__.py:23
#      20 from typing import Callable, TYPE_CHECKING
#      22 import torch
# ---> 23 from torch.onnx.ops import _impl, _symbolic_impl
#      26 if TYPE_CHECKING:
#      27     from collections.abc import Sequence
#
# File ~/Projects/Coding/biblioteca/.venv/lib/python3.11/site-packages/torch/onnx/ops/_impl.py:7
#       4 from typing import Callable, Optional
#       6 import torch
# ----> 7 from torch.onnx.ops import _dtype_mappings
#      10 _T = typing.TypeVar("_T", bound=Callable)
#      12 # ONNX to ATen decomp table
#
# File ~/Projects/Coding/biblioteca/.venv/lib/python3.11/site-packages/torch/onnx/ops/_dtype_mappings.py:26
#       1 import torch
#       4 ONNX_DTYPE_TO_TORCH_DTYPE: dict[int, torch.dtype] = {
#       5     1: torch.float32,  # FLOAT
#       6     2: torch.uint8,  # UINT8
#       7     3: torch.int8,  # INT8
#       8     4: torch.uint16,  # UINT16
#       9     5: torch.int16,  # INT16
#      10     6: torch.int32,  # INT32
#      11     7: torch.int64,  # INT64
#      12     9: torch.bool,  # BOOL
#      13     10: torch.float16,  # FLOAT16
#      14     11: torch.double,  # DOUBLE
#      15     12: torch.uint32,  # UINT32
#      16     13: torch.uint64,  # UINT64
#      17     14: torch.complex64,  # COMPLEX64
#      18     15: torch.complex128,  # COMPLEX128
#      19     16: torch.bfloat16,  # BFLOAT16
#      20     17: torch.float8_e4m3fn,  # FLOAT8E4M3FN
#      21     18: torch.float8_e4m3fnuz,  # FLOAT8E4M3FNUZ
#      22     19: torch.float8_e5m2,  # FLOAT8E5M2
#      23     20: torch.float8_e5m2fnuz,  # FLOAT8E5M2FNUZ
#      24     21: torch.uint8,  # UINT4
#      25     22: torch.uint8,  # INT4
# ---> 26     23: torch.float4_e2m1fn_x2,  # FLOAT4E2M1
#      27 }
#
# File ~/Projects/Coding/biblioteca/.venv/lib/python3.11/site-packages/torch/__init__.py:2688, in __getattr__(name)
#    2687 class _TritonLibrary:
# -> 2688     lib = torch.library.Library("triton", "DEF")
#    2689     ops_table: dict[tuple[str, str], _Callable] = {}
#    2691     @classmethod
#    2692     def registerOp(cls, op_key, full_schema, op_impl, dispatch_key):
#
# AttributeError: module 'torch' has no attribute 'float4_e2m1fn_x2'

# %% [markdown]
# ## Loading the Images
#
# We load the images first using PIL.

# %%
IMAGE_DIR = "./img"
OUTPUT_DIR = "./output"

pil_images = []

for item in os.iterdir(IMAGE_DIR):
    print(item)
